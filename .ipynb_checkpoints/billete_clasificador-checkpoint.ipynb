# %%
import torch 
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, models, transforms 
import numpy as np 
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import os
import copy

# %% [markdown]
# # Load Data

# %%
data_transforms = {
    'train' : transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val' : transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    
}

data_dir = 'dataset_billete_argentino'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                              shuffle=True, num_workers=4)
               for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_name = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Visualize a few images

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)
    
    
# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_name[x] for x in classes])

# %% [markdown]
# # Creating the Neural Network

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3,6,5)
        self.pool = nn.MaxPool2d(2,2)
        self.conv2 = nn.Conv2d(6,16,5)
        self.fc1 = nn.Linear(16 * 53 * 53, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 2)
    
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(x.size(0), 16* 53 * 53)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net = Net()

# %%
print(net)
# Out:
# Net(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=2, bias=True)
# )

# %% [markdown]
# # Define a Loss function and optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# # Visualizing the model predictions

# %%
def visualize_model(model, num_images=20):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_name[preds[j]]))
                ax = plt.figure(figsize=(10, 10))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
# check if GPU is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('Bummer!  Training on CPU ...')
else:
    print('You are good to go!  Training on GPU ...')
# Out:
# Bummer!  Training on CPU ...

# %% [markdown]
# # Train and evaluate

# %%
from torch.optim import lr_scheduler

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

net = train_model(net, criterion, optimizer, exp_lr_scheduler,
                  num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.7106 Acc: 0.4917
# val Loss: 0.6720 Acc: 0.5000
#
# Epoch 1/24
# ----------
# train Loss: 0.7327 Acc: 0.5500
# val Loss: 0.6858 Acc: 0.5000
#
# Epoch 2/24
# ----------
# train Loss: 0.7464 Acc: 0.4500
# val Loss: 0.6940 Acc: 0.6176
#
# Epoch 3/24
# ----------
# train Loss: 0.7183 Acc: 0.5500
# val Loss: 0.6809 Acc: 0.6176
#
# Epoch 4/24
# ----------
# train Loss: 0.6690 Acc: 0.5250
# val Loss: 0.5016 Acc: 0.8529
#
# Epoch 5/24
# ----------
# train Loss: 0.3947 Acc: 0.8500
# val Loss: 0.5494 Acc: 0.7647
#
# Epoch 6/24
# ----------
# train Loss: 0.5292 Acc: 0.7917
# val Loss: 0.4911 Acc: 0.7059
#
# Epoch 7/24
# ----------
# train Loss: 0.4072 Acc: 0.8333
# val Loss: 0.4049 Acc: 0.8235
#
# Epoch 8/24
# ----------
# train Loss: 0.3753 Acc: 0.8583
# val Loss: 0.3673 Acc: 0.8529
#
# Epoch 9/24
# ----------
# train Loss: 0.3029 Acc: 0.8833
# val Loss: 0.3314 Acc: 0.8529
#
# Epoch 10/24
# ----------
# train Loss: 0.3353 Acc: 0.8583
# val Loss: 0.3188 Acc: 0.8235
#
# Epoch 11/24
# ----------
# train Loss: 0.3280 Acc: 0.8583
# val Loss: 0.3151 Acc: 0.8235
#
# Epoch 12/24
# ----------
# train Loss: 0.3148 Acc: 0.8500
# val Loss: 0.2906 Acc: 0.7941
#
# Epoch 13/24
# ----------
# train Loss: 0.3829 Acc: 0.8333
# val Loss: 0.2368 Acc: 0.9118
#
# Epoch 14/24
# ----------
# train Loss: 0.3349 Acc: 0.8250
# val Loss: 0.2637 Acc: 0.8824
#
# Epoch 15/24
# ----------
# train Loss: 0.3034 Acc: 0.8583
# val Loss: 0.2722 Acc: 0.8529
#
# Epoch 16/24
# ----------
# train Loss: 0.2680 Acc: 0.8917
# val Loss: 0.2729 Acc: 0.8529
#
# Epoch 17/24
# ----------
# train Loss: 0.2568 Acc: 0.8917
# val Loss: 0.2670 Acc: 0.8235
#
# Epoch 18/24
# ----------
# train Loss: 0.2946 Acc: 0.8667
# val Loss: 0.2637 Acc: 0.8824
#
# Epoch 19/24
# ----------
# train Loss: 0.3452 Acc: 0.8500
# val Loss: 0.2603 Acc: 0.8824
#
# Epoch 20/24
# ----------
# train Loss: 0.3142 Acc: 0.8667
# val Loss: 0.2663 Acc: 0.8529
#
# Epoch 21/24
# ----------
# train Loss: 0.3080 Acc: 0.9083
# val Loss: 0.2638 Acc: 0.8824
#
# Epoch 22/24
# ----------
# train Loss: 0.2887 Acc: 0.8833
# val Loss: 0.2659 Acc: 0.8529
#
# Epoch 23/24
# ----------
# train Loss: 0.3105 Acc: 0.8417
# val Loss: 0.2662 Acc: 0.8529
#
# Epoch 24/24
# ----------
# train Loss: 0.3147 Acc: 0.8750
# val Loss: 0.2667 Acc: 0.8529
#
# Training complete in 7m 27s
# Best val Acc: 0.911765

# %%
visualize_model(net)

# %%
PATH = './clasificador_billetes_01'
torch.save(net.state_dict(), PATH)
